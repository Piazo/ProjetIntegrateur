# %%
import pandas as pd
import sklearn
import csv
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
df = pd.read_csv("./data/value.csv", sep = ";")
df
# Out:
#        Latence1  Latence2  Latence3  CPU1  RAM1  CPU2  RAM2  CPU3  RAM3  \
# 0      0.168295  0.250647  0.175589  0.36   0.7  0.30   0.7  0.80   0.7
# 1      0.110052  0.242842  0.097456  0.69   0.4  0.50   0.5  0.17   0.7
# 2      0.468962  0.242266  0.137896  0.93   0.6  0.73   0.7  0.83   0.7
# 3      0.380637  0.169424  0.122439  0.30   0.7  0.59   0.4  0.62   0.4
# 4      0.173749  0.189239  0.230444  0.44   0.7  0.68   0.3  0.33   0.4
# ...         ...       ...       ...   ...   ...   ...   ...   ...   ...
# 19995  0.353395  0.207639  0.241753  0.59   0.4  0.26   0.3  0.23   0.4
# 19996  0.366271  0.110511  0.322599  0.36   0.3  0.28   0.4  0.28   0.7
# 19997  0.308927  0.118603  0.338697  0.80   0.3  0.46   0.3  0.46   0.3
# 19998  0.294975  0.206861  0.164883  0.71   0.5  0.18   0.7  0.79   0.7
# 19999  0.490751  0.246697  0.363048  0.61   0.3  0.77   0.8  0.23   0.6
#
#        Coord1  Coord2
# 0           3       1
# 1           1       5
# 2           2       1
# 3           0       0
# 4           0       3
# ...       ...     ...
# 19995       0       3
# 19996       3       1
# 19997       0       5
# 19998       0       2
# 19999       4       4
#
# [20000 rows x 11 columns]

# %%
df.dtypes
# Out:
# Latence1    float64
# Latence2    float64
# Latence3    float64
# CPU1        float64
# RAM1        float64
# CPU2        float64
# RAM2        float64
# CPU3        float64
# RAM3        float64
# Coord1        int64
# Coord2        int64
# dtype: object

# %%
df1= df[["Latence1","CPU1","RAM1"]].copy()
df1 = df1.rename(columns={'Latence1': 'Latence', 'CPU1': 'CPU','RAM1': 'RAM'})
df1['Node']=1
df1
# Out:
#         Latence   CPU  RAM  Node
# 0      0.168295  0.36  0.7     1
# 1      0.110052  0.69  0.4     1
# 2      0.468962  0.93  0.6     1
# 3      0.380637  0.30  0.7     1
# 4      0.173749  0.44  0.7     1
# ...         ...   ...  ...   ...
# 19995  0.353395  0.59  0.4     1
# 19996  0.366271  0.36  0.3     1
# 19997  0.308927  0.80  0.3     1
# 19998  0.294975  0.71  0.5     1
# 19999  0.490751  0.61  0.3     1
#
# [20000 rows x 4 columns]

# %%
df2= df[["Latence2","CPU2","RAM2"]].copy()
df2 = df2.rename(columns={'Latence2': 'Latence', 'CPU2': 'CPU','RAM2': 'RAM'})
df2['Node']=2
df2
# Out:
#         Latence   CPU  RAM  Node
# 0      0.250647  0.30  0.7     2
# 1      0.242842  0.50  0.5     2
# 2      0.242266  0.73  0.7     2
# 3      0.169424  0.59  0.4     2
# 4      0.189239  0.68  0.3     2
# ...         ...   ...  ...   ...
# 19995  0.207639  0.26  0.3     2
# 19996  0.110511  0.28  0.4     2
# 19997  0.118603  0.46  0.3     2
# 19998  0.206861  0.18  0.7     2
# 19999  0.246697  0.77  0.8     2
#
# [20000 rows x 4 columns]

# %%
df3= df[["Latence3","CPU3","RAM3"]].copy()
df3 = df3.rename(columns={'Latence3': 'Latence', 'CPU3': 'CPU','RAM3': 'RAM'})
df3['Node']=3
df3
# Out:
#         Latence   CPU  RAM  Node
# 0      0.175589  0.80  0.7     3
# 1      0.097456  0.17  0.7     3
# 2      0.137896  0.83  0.7     3
# 3      0.122439  0.62  0.4     3
# 4      0.230444  0.33  0.4     3
# ...         ...   ...  ...   ...
# 19995  0.241753  0.23  0.4     3
# 19996  0.322599  0.28  0.7     3
# 19997  0.338697  0.46  0.3     3
# 19998  0.164883  0.79  0.7     3
# 19999  0.363048  0.23  0.6     3
#
# [20000 rows x 4 columns]

# %%
frames = [df1, df2, df3]
df_new = pd.concat(frames)
df_new
# Out:
#         Latence   CPU  RAM  Node
# 0      0.168295  0.36  0.7     1
# 1      0.110052  0.69  0.4     1
# 2      0.468962  0.93  0.6     1
# 3      0.380637  0.30  0.7     1
# 4      0.173749  0.44  0.7     1
# ...         ...   ...  ...   ...
# 19995  0.241753  0.23  0.4     3
# 19996  0.322599  0.28  0.7     3
# 19997  0.338697  0.46  0.3     3
# 19998  0.164883  0.79  0.7     3
# 19999  0.363048  0.23  0.6     3
#
# [60000 rows x 4 columns]

# %%
# Extraction des échantillons apprentissage et test
y= df["Latence1"].copy()
x= df["Latence1"].copy()
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 80 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 203, in fit
#     check_classification_targets(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\utils\multiclass.py", line 197, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [78], in <cell line: 10>()
#       2 grid = [{"max_depth":list(range(2,10))}]
#       4 decision_tree = GridSearchCV(
#       5     DecisionTreeClassifier(),
#       6     grid,
#       7     cv = 10,
#       8 )
# ---> 10 decision_tree = decision_tree.fit(X_train, y_train)
#      12 # paramètre optimal
#      13 f"Meilleur score = {1. - decision_tree.best_score_:f}, meilleur paramètre: {decision_tree.best_params_}"
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     924 refit_start_time = time.time()
#     925 if y is not None:
# --> 926     self.best_estimator_.fit(X, y, **fit_params)
#     927 else:
#     928     self.best_estimator_.fit(X, **fit_params)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:203, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     200 self.n_outputs_ = y.shape[1]
#     202 if is_classification:
# --> 203     check_classification_targets(y)
#     204     y = np.copy(y)
#     206     self.classes_ = []
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py:197, in check_classification_targets(y)
#     189 y_type = type_of_target(y)
#     190 if y_type not in [
#     191     "binary",
#     192     "multiclass",
#    (...)
#     195     "multilabel-sequences",
#     196 ]:
# --> 197     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
# !{sys.executable} -m pip install tenserflow
# Out:
# '{sys.executable}' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [75], in <cell line: 3>()
#       1 get_ipython().system('{sys.executable} -m pip install tenserflow')
#       2 from sklearn.neural_network import MLPClassifier
# ----> 3 from tensorflow.keras import models, layers, utils, backend as K
#       4 import shap
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 40 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1131, in _validate_input
#     self._label_binarizer.fit(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py", line 301, in fit
#     self.classes_ = unique_labels(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\utils\multiclass.py", line 101, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.49641845, 0.30836118, 0.19009958, ..., 0.43810409, 0.132148  ,
#        0.06860163]),)
#
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1131, in _validate_input
#     self._label_binarizer.fit(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py", line 301, in fit
#     self.classes_ = unique_labels(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\utils\multiclass.py", line 101, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.09293766, 0.14893781, 0.22992919, ..., 0.43810409, 0.132148  ,
#        0.06860163]),)
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1131, in _validate_input
#     self._label_binarizer.fit(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py", line 301, in fit
#     self.classes_ = unique_labels(y)
#   File "C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\utils\multiclass.py", line 101, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.09293766, 0.14893781, 0.22992919, ..., 0.12595267, 0.24014415,
#        0.06803333]),)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [72], in <cell line: 11>()
#       3 grid = [{"hidden_layer_sizes":list([(5,),(6,),(7,),(8,)])}]
#       5 neural_network = GridSearchCV(
#       6     MLPClassifier(max_iter=20000, warm_start=True, random_state=42),
#       7     grid,
#       8     cv = 10,
#       9 )
# ---> 11 neural_network = neural_network.fit(X_train, y_train)
#      13 # paramètre optimal
#      14 f"Meilleur score = {1.- neural_network.best_score_:f}, meilleur paramètre: {neural_network.best_params_}"
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     924 refit_start_time = time.time()
#     925 if y is not None:
# --> 926     self.best_estimator_.fit(X, y, **fit_params)
#     927 else:
#     928     self.best_estimator_.fit(X, **fit_params)
#
# File ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:752, in BaseMultilayerPerceptron.fit(self, X, y)
#     735 def fit(self, X, y):
#     736     """Fit the model to data matrix X and target(s) y.
#     737
#     738     Parameters
#    (...)
#     750         Returns a trained MLP model.
#     751     """
# --> 752     return self._fit(X, y, incremental=False)
#
# File ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:393, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     386     raise ValueError(
#     387         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     388     )
#     389 first_pass = not hasattr(self, "coefs_") or (
#     390     not self.warm_start and not incremental
#     391 )
# --> 393 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     395 n_samples, n_features = X.shape
#     397 # Ensure y is 2D
#
# File ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1131, in MLPClassifier._validate_input(self, X, y, incremental, reset)
#    1129 if (not hasattr(self, "classes_")) or (not self.warm_start and not incremental):
#    1130     self._label_binarizer = LabelBinarizer()
# -> 1131     self._label_binarizer.fit(y)
#    1132     self.classes_ = self._label_binarizer.classes_
#    1133 else:
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:301, in LabelBinarizer.fit(self, y)
#     298     raise ValueError("y has 0 samples: %r" % y)
#     300 self.sparse_input_ = sp.issparse(y)
# --> 301 self.classes_ = unique_labels(y)
#     302 return self
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py:101, in unique_labels(*ys)
#      99 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     100 if not _unique_labels:
# --> 101     raise ValueError("Unknown label type: %s" % repr(ys))
#     103 ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#     105 # Check that we don't mix string type with number type
#
# ValueError: Unknown label type: (array([0.09293766, 0.14893781, 0.22992919, ..., 0.43810409, 0.132148  ,
#        0.06860163]),)
